# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('Attrition data.csv')
df
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
from sklearn import preprocessing 

obj = list(df.select_dtypes(include=['object']).columns)
df[obj]
label_encoder = preprocessing.LabelEncoder() 
for col in obj:
    df[col] = label_encoder.fit_transform(df[col])
df
# Out:
#       EmployeeID  Age  Attrition  BusinessTravel  Department  \
# 0              1   51          0               2           2
# 1              2   31          1               1           1
# 2              3   32          0               1           1
# 3              4   38          0               0           1
# 4              5   32          0               2           1
# ...          ...  ...        ...             ...         ...
# 4405        4406   42          0               2           1
# 4406        4407   29          0               2           1
# 4407        4408   25          0               2           1
# 4408        4409   42          0               2           2
# 4409        4410   40          0               2           1
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  Gender  ...  \
# 0                    6          2               1              1       0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   int32
#  3   BusinessTravel           4410 non-null   int32
#  4   Department               4410 non-null   int32
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   int32
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   int32
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   int32
#  12  MaritalStatus            4410 non-null   int32
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
df["NumCompaniesWorked"].fillna( method ='ffill', inplace = True) 
df["EnvironmentSatisfaction"].fillna( method ='ffill', inplace = True)
df["JobSatisfaction"].fillna( method ='ffill', inplace = True)
df["WorkLifeBalance"].fillna( method ='ffill', inplace = True)

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          9
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64

# %%
df=df.drop(['Over18','StandardHours','EmployeeCount'],axis=1)
df
# Out:
#       EmployeeID  Age  Attrition  BusinessTravel  Department  \
# 0              1   51          0               2           2
# 1              2   31          1               1           1
# 2              3   32          0               1           1
# 3              4   38          0               0           1
# 4              5   32          0               2           1
# ...          ...  ...        ...             ...         ...
# 4405        4406   42          0               2           1
# 4406        4407   29          0               2           1
# 4407        4408   25          0               2           1
# 4408        4409   42          0               2           2
# 4409        4410   40          0               2           1
#
#       DistanceFromHome  Education  EducationField  Gender  JobLevel  ...  \
# 0                    6          2               1       0         1  ...
# 1                   10          1               1       0         1  ...
# ...

# %%
df=df.drop(['PercentSalaryHike','Age','YearsWithCurrManager'],axis=1)
df
# Out:
#       EmployeeID  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0              1          0               2           2                 6
# 1              2          1               1           1                10
# 2              3          0               1           1                17
# 3              4          0               0           1                 2
# 4              5          0               2           1                10
# ...          ...        ...             ...         ...               ...
# 4405        4406          0               2           1                 5
# 4406        4407          0               2           1                 2
# 4407        4408          0               2           1                25
# 4408        4409          0               2           2                18
# 4409        4410          0               2           1                28
#
#       Education  EducationField  Gender  JobLevel  JobRole  ...  \
# ...

# %%
matrix1=df.corr()
matrix1
# Out:
#                          EmployeeID  Attrition  BusinessTravel  Department  \
# EmployeeID                 1.000000  -0.004729       -0.002590   -0.003455
# Attrition                 -0.004729   1.000000        0.000074   -0.048206
# BusinessTravel            -0.002590   0.000074        1.000000   -0.010982
# Department                -0.003455  -0.048206       -0.010982    1.000000
# DistanceFromHome          -0.001097  -0.009730        0.024616    0.012134
# Education                 -0.009680  -0.015111        0.002755   -0.004597
# EducationField            -0.000819  -0.057940       -0.015462    0.013720
# Gender                    -0.013165   0.018125       -0.039243    0.003158
# JobLevel                  -0.003303  -0.010290        0.046111    0.002923
# JobRole                    0.005767   0.025809       -0.027194   -0.025466
# MaritalStatus              0.001337   0.162070        0.024001   -0.044619
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(30,30)) 
sns.heatmap(matrix1,cmap='coolwarm', linewidths=.2, annot=True,ax=ax)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# StockOptionLevel           0
# TotalWorkingYears          9
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['EmployeeID', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'EnvironmentSatisfaction',
#        'JobSatisfaction', 'WorkLifeBalance', 'JobInvolvement',
#        'PerformanceRating'],
#       dtype='object')

# %%
zero_counts = (df == 0).sum()
columns_with_zero = zero_counts[zero_counts > 0]
print(columns_with_zero)
# Out:
# Attrition                  3699
# BusinessTravel              450
# Department                  189
# EducationField               81
# Gender                     1764
# JobRole                     393
# MaritalStatus               981
# NumCompaniesWorked          588
# StockOptionLevel           1893
# TotalWorkingYears            33
# TrainingTimesLastYear       162
# YearsAtCompany              132
# YearsSinceLastPromotion    1743
# dtype: int64

# %%
columns_to_replace = ['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','NumCompaniesWorked', 
   'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsSinceLastPromotion']
df[columns_to_replace] = df[columns_to_replace].replace(0,1).fillna(method='ffill')
df
# Out:
#       EmployeeID  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0              1          1               2           2                 6
# 1              2          1               1           1                10
# 2              3          1               1           1                17
# 3              4          1               1           1                 2
# 4              5          1               2           1                10
# ...          ...        ...             ...         ...               ...
# 4405        4406          1               2           1                 5
# 4406        4407          1               2           1                 2
# 4407        4408          1               2           1                25
# 4408        4409          1               2           2                18
# 4409        4410          1               2           1                28
#
#       Education  EducationField  Gender  JobLevel  JobRole  ...  \
# ...

# %%
columns_to_replace = ['Attrition','Gender','JobRole','StockOptionLevel','YearsSinceLastPromotion']
df[columns_to_replace] = df[columns_to_replace].replace(0, np.nan).fillna(method='ffill')
df
# Out:
#       EmployeeID  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0              1          1               2           2                 6
# 1              2          1               1           1                10
# 2              3          1               1           1                17
# 3              4          1               1           1                 2
# 4              5          1               2           1                10
# ...          ...        ...             ...         ...               ...
# 4405        4406          1               2           1                 5
# 4406        4407          1               2           1                 2
# 4407        4408          1               2           1                25
# 4408        4409          1               2           2                18
# 4409        4410          1               2           1                28
#
#       Education  EducationField  Gender  JobLevel  JobRole  ...  \
# ...

# %%
nan_in_columns = df.isnull().any()

print("NaN values present in each column:\n", nan_in_columns)
# Out:
# NaN values present in each column:
#  EmployeeID                 False
# Attrition                  False
# BusinessTravel             False
# Department                 False
# DistanceFromHome           False
# Education                  False
# EducationField             False
# Gender                     False
# JobLevel                   False
# JobRole                    False
# MaritalStatus              False
# MonthlyIncome              False
# NumCompaniesWorked         False
# StockOptionLevel           False
# TotalWorkingYears          False
# TrainingTimesLastYear      False
# YearsAtCompany             False
# YearsSinceLastPromotion    False
# EnvironmentSatisfaction    False
# JobSatisfaction            False
# WorkLifeBalance            False
# JobInvolvement             False
# PerformanceRating          False
# dtype: bool

# %%
X = df.iloc[:,:-1].values
Y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.7, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=42, max_iter=5000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('Y_pred', y_pred)
print('Y_test', y_test)
# Out:
# Y_pred [3 3 3 ... 3 3 3]
# Y_test [3 3 3 ... 3 3 3]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

accuracy=accuracy_score(y_test,y_pred)*100
print("Accuracy of the model is {:.2f}".format(accuracy))
# Out:
# Accuracy of the model is 84.73

# %%
from sklearn.metrics import classification_report
cf1=classification_report(y_pred,y_test)

print('Classification_report:\n', cf1)
# Out:
# Classification_report:
#                precision    recall  f1-score   support
#
#            3       1.00      0.85      0.92      1323
#            4       0.00      0.00      0.00         0
#
#     accuracy                           0.85      1323
#    macro avg       0.50      0.42      0.46      1323
# weighted avg       1.00      0.85      0.92      1323
# C:\Users\prash\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\prash\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
